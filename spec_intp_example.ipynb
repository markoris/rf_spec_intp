# %%
## Data retrieval

# Obtain data from Zenodo if not already downloaded (~10 GB)
# This will take some time!

import subprocess
#subprocess.call('wget https://zenodo.org/record/7335961/files/active_learning_sims.tar.gz', shell=True)

# Strongly suggest using something like aria2 for speed-up
# Remove "-q" flag for verbose output

subprocess.call('aria2c --file-allocation=none -c -x 10 -s 10 -q \
https://zenodo.org/record/7335961/files/active_learning_sims.tar.gz', shell=True)

# An output of "0" indicates success!

# %%
## Data setup

# Untar the data

subprocess.call('tar -zxf active_learning_sims.tar.gz', shell=True)

# %%
## Data setup

# Optional: once downloaded, convert spectra to hdf5 format
# This takes about an hour, but it's a one-time thing and
# will *significantly* increase IO during training
# Training script will require reformatting if not using hdf5 spectra

import convert_dat_to_h5 as convh5

convh5.convert_dat_to_h5(path_to_sims_dir='knsc1_active_learning', \
                         path_to_h5_out='TP_wind2_spectra.h5', \
                         cutoff=21) # going out to about 3 weeks
# Out:
# Converting spectra .dat files from knsc1_active_learning
# Outputting spectra .hdf5 file to TP_wind2_spectra.h5
# Using 60 time iterations with a maximum time of 21
# Concatenated 1 out of 412 spectra
# Concatenated 2 out of 412 spectra
# Concatenated 3 out of 412 spectra
# Concatenated 4 out of 412 spectra
# Concatenated 5 out of 412 spectra
# Concatenated 6 out of 412 spectra
# Concatenated 7 out of 412 spectra
# Concatenated 8 out of 412 spectra
# Concatenated 9 out of 412 spectra
# Concatenated 10 out of 412 spectra
# Concatenated 11 out of 412 spectra
# Concatenated 12 out of 412 spectra
# Concatenated 13 out of 412 spectra
# Concatenated 14 out of 412 spectra
# Concatenated 15 out of 412 spectra
# Concatenated 16 out of 412 spectra
# Concatenated 17 out of 412 spectra
# Concatenated 18 out of 412 spectra
# Concatenated 19 out of 412 spectra
# Concatenated 20 out of 412 spectra
# Concatenated 21 out of 412 spectra
# Concatenated 22 out of 412 spectra
# Concatenated 23 out of 412 spectra
# Concatenated 24 out of 412 spectra
# Concatenated 25 out of 412 spectra
# Concatenated 26 out of 412 spectra
# Concatenated 27 out of 412 spectra
# Concatenated 28 out of 412 spectra
# Concatenated 29 out of 412 spectra
# Concatenated 30 out of 412 spectra
# Concatenated 31 out of 412 spectra
# Concatenated 32 out of 412 spectra
# Concatenated 33 out of 412 spectra
# Concatenated 34 out of 412 spectra
# Concatenated 35 out of 412 spectra
# Concatenated 36 out of 412 spectra
# Concatenated 37 out of 412 spectra
# Concatenated 38 out of 412 spectra
# Concatenated 39 out of 412 spectra
# Concatenated 40 out of 412 spectra
# Concatenated 41 out of 412 spectra
# Concatenated 42 out of 412 spectra
# Concatenated 43 out of 412 spectra
# Concatenated 44 out of 412 spectra
# Concatenated 45 out of 412 spectra
# Concatenated 46 out of 412 spectra
# Concatenated 47 out of 412 spectra
# Concatenated 48 out of 412 spectra
# Concatenated 49 out of 412 spectra
# Concatenated 50 out of 412 spectra
# Concatenated 51 out of 412 spectra
# Concatenated 52 out of 412 spectra
# Concatenated 53 out of 412 spectra
# Concatenated 54 out of 412 spectra
# Concatenated 55 out of 412 spectra
# Concatenated 56 out of 412 spectra
# Concatenated 57 out of 412 spectra
# Concatenated 58 out of 412 spectra
# Concatenated 60 out of 412 spectra
# Concatenated 61 out of 412 spectra
# Concatenated 62 out of 412 spectra
# Concatenated 63 out of 412 spectra
# Concatenated 64 out of 412 spectra
# Concatenated 65 out of 412 spectra
# Concatenated 66 out of 412 spectra
# Concatenated 67 out of 412 spectra
# Concatenated 68 out of 412 spectra
# Concatenated 69 out of 412 spectra
# Concatenated 70 out of 412 spectra
# Concatenated 71 out of 412 spectra
# Concatenated 72 out of 412 spectra
# Concatenated 73 out of 412 spectra
# Concatenated 74 out of 412 spectra
# Concatenated 75 out of 412 spectra
# Concatenated 76 out of 412 spectra
# Concatenated 77 out of 412 spectra
# Concatenated 78 out of 412 spectra
# Concatenated 79 out of 412 spectra
# Concatenated 80 out of 412 spectra
# Concatenated 81 out of 412 spectra
# Concatenated 82 out of 412 spectra
# Concatenated 83 out of 412 spectra
# Concatenated 84 out of 412 spectra
# Concatenated 85 out of 412 spectra
# Concatenated 86 out of 412 spectra
# Concatenated 87 out of 412 spectra
# Concatenated 88 out of 412 spectra
# Concatenated 89 out of 412 spectra
# Concatenated 90 out of 412 spectra
# Concatenated 91 out of 412 spectra
# Concatenated 92 out of 412 spectra
# Concatenated 93 out of 412 spectra
# Concatenated 94 out of 412 spectra
# Concatenated 95 out of 412 spectra
# Concatenated 96 out of 412 spectra
# Concatenated 97 out of 412 spectra
# Concatenated 98 out of 412 spectra
# Concatenated 99 out of 412 spectra
# Concatenated 100 out of 412 spectra
# Concatenated 101 out of 412 spectra
# Concatenated 102 out of 412 spectra
# Concatenated 103 out of 412 spectra
# Concatenated 104 out of 412 spectra
# Concatenated 105 out of 412 spectra
# Concatenated 106 out of 412 spectra
# Concatenated 107 out of 412 spectra
# Concatenated 108 out of 412 spectra
# Concatenated 109 out of 412 spectra
# Concatenated 110 out of 412 spectra
# Concatenated 111 out of 412 spectra
# Concatenated 112 out of 412 spectra
# Concatenated 113 out of 412 spectra
# Concatenated 114 out of 412 spectra
# Concatenated 115 out of 412 spectra
# Concatenated 116 out of 412 spectra
# Concatenated 117 out of 412 spectra
# Concatenated 118 out of 412 spectra
# Concatenated 120 out of 412 spectra
# Concatenated 121 out of 412 spectra
# Concatenated 122 out of 412 spectra
# Concatenated 123 out of 412 spectra
# Concatenated 124 out of 412 spectra
# Concatenated 125 out of 412 spectra
# Concatenated 126 out of 412 spectra
# Concatenated 127 out of 412 spectra
# Concatenated 128 out of 412 spectra
# Concatenated 129 out of 412 spectra
# Concatenated 130 out of 412 spectra
# Concatenated 131 out of 412 spectra
# Concatenated 132 out of 412 spectra
# Concatenated 133 out of 412 spectra
# Concatenated 134 out of 412 spectra
# Concatenated 135 out of 412 spectra
# Concatenated 136 out of 412 spectra
# Concatenated 137 out of 412 spectra
# Concatenated 138 out of 412 spectra
# Concatenated 139 out of 412 spectra
# Concatenated 140 out of 412 spectra
# Concatenated 141 out of 412 spectra
# Concatenated 142 out of 412 spectra
# Concatenated 143 out of 412 spectra
# Concatenated 144 out of 412 spectra
# Concatenated 145 out of 412 spectra
# Concatenated 146 out of 412 spectra
# Concatenated 147 out of 412 spectra
# Concatenated 148 out of 412 spectra
# Concatenated 149 out of 412 spectra
# Concatenated 150 out of 412 spectra
# Concatenated 151 out of 412 spectra
# Concatenated 152 out of 412 spectra
# Concatenated 153 out of 412 spectra
# Concatenated 154 out of 412 spectra
# Concatenated 155 out of 412 spectra
# Concatenated 156 out of 412 spectra
# Concatenated 157 out of 412 spectra
# Concatenated 158 out of 412 spectra
# Concatenated 159 out of 412 spectra
# Concatenated 160 out of 412 spectra
# Concatenated 161 out of 412 spectra
# Concatenated 162 out of 412 spectra
# Concatenated 163 out of 412 spectra
# Concatenated 164 out of 412 spectra
# Concatenated 165 out of 412 spectra
# Concatenated 166 out of 412 spectra
# Concatenated 167 out of 412 spectra
# Concatenated 168 out of 412 spectra
# Concatenated 169 out of 412 spectra
# Concatenated 170 out of 412 spectra
# Concatenated 171 out of 412 spectra
# Concatenated 172 out of 412 spectra
# Concatenated 173 out of 412 spectra
# Concatenated 174 out of 412 spectra
# Concatenated 175 out of 412 spectra
# Concatenated 176 out of 412 spectra
# Concatenated 177 out of 412 spectra
# Concatenated 178 out of 412 spectra
# Concatenated 180 out of 412 spectra
# Concatenated 181 out of 412 spectra
# Concatenated 182 out of 412 spectra
# Concatenated 183 out of 412 spectra
# Concatenated 184 out of 412 spectra
# Concatenated 185 out of 412 spectra
# Concatenated 186 out of 412 spectra
# Concatenated 187 out of 412 spectra
# Concatenated 188 out of 412 spectra
# Concatenated 189 out of 412 spectra
# Concatenated 190 out of 412 spectra
# Concatenated 191 out of 412 spectra
# Concatenated 192 out of 412 spectra
# Concatenated 193 out of 412 spectra
# Concatenated 194 out of 412 spectra
# Concatenated 195 out of 412 spectra
# Concatenated 196 out of 412 spectra
# Concatenated 197 out of 412 spectra
# Concatenated 198 out of 412 spectra
# Concatenated 199 out of 412 spectra
# Concatenated 200 out of 412 spectra
# Concatenated 201 out of 412 spectra
# Concatenated 202 out of 412 spectra
# Concatenated 203 out of 412 spectra
# Concatenated 204 out of 412 spectra
# Concatenated 205 out of 412 spectra
# Concatenated 206 out of 412 spectra
# Concatenated 207 out of 412 spectra
# Concatenated 208 out of 412 spectra
# Concatenated 209 out of 412 spectra
# Concatenated 210 out of 412 spectra
# Concatenated 211 out of 412 spectra
# Concatenated 212 out of 412 spectra
# Concatenated 213 out of 412 spectra
# Concatenated 214 out of 412 spectra
# Concatenated 215 out of 412 spectra
# Concatenated 216 out of 412 spectra
# Concatenated 217 out of 412 spectra
# Concatenated 218 out of 412 spectra
# Concatenated 219 out of 412 spectra
# Concatenated 220 out of 412 spectra
# Concatenated 221 out of 412 spectra
# Concatenated 222 out of 412 spectra
# Concatenated 223 out of 412 spectra
# Concatenated 224 out of 412 spectra
# Concatenated 225 out of 412 spectra
# Concatenated 226 out of 412 spectra
# Concatenated 227 out of 412 spectra
# Concatenated 228 out of 412 spectra
# Concatenated 229 out of 412 spectra
# Concatenated 230 out of 412 spectra
# Concatenated 231 out of 412 spectra
# Concatenated 232 out of 412 spectra
# Concatenated 233 out of 412 spectra
# Concatenated 234 out of 412 spectra
# Concatenated 235 out of 412 spectra
# Concatenated 236 out of 412 spectra
# Concatenated 237 out of 412 spectra
# Concatenated 238 out of 412 spectra
# Concatenated 240 out of 412 spectra
# Concatenated 241 out of 412 spectra
# Concatenated 242 out of 412 spectra
# Concatenated 243 out of 412 spectra
# Concatenated 244 out of 412 spectra
# Concatenated 245 out of 412 spectra
# Concatenated 246 out of 412 spectra
# Concatenated 247 out of 412 spectra
# Concatenated 248 out of 412 spectra
# Concatenated 249 out of 412 spectra
# Concatenated 250 out of 412 spectra
# Concatenated 251 out of 412 spectra
# Concatenated 252 out of 412 spectra
# Concatenated 253 out of 412 spectra
# Concatenated 254 out of 412 spectra
# Concatenated 255 out of 412 spectra
# Concatenated 256 out of 412 spectra
# Concatenated 257 out of 412 spectra
# Concatenated 258 out of 412 spectra
# Concatenated 259 out of 412 spectra
# Concatenated 260 out of 412 spectra
# Concatenated 261 out of 412 spectra
# Concatenated 262 out of 412 spectra
# Concatenated 263 out of 412 spectra
# Concatenated 264 out of 412 spectra
# Concatenated 265 out of 412 spectra
# Concatenated 266 out of 412 spectra
# Concatenated 267 out of 412 spectra
# Concatenated 268 out of 412 spectra
# Concatenated 269 out of 412 spectra
# Concatenated 270 out of 412 spectra
# Concatenated 271 out of 412 spectra
# Concatenated 272 out of 412 spectra
# Concatenated 273 out of 412 spectra
# Concatenated 274 out of 412 spectra
# Concatenated 275 out of 412 spectra
# Concatenated 276 out of 412 spectra
# Concatenated 277 out of 412 spectra
# Concatenated 278 out of 412 spectra
# Concatenated 279 out of 412 spectra
# Concatenated 280 out of 412 spectra
# Concatenated 281 out of 412 spectra
# Concatenated 282 out of 412 spectra
# Concatenated 283 out of 412 spectra
# Concatenated 284 out of 412 spectra
# Concatenated 285 out of 412 spectra
# Concatenated 286 out of 412 spectra
# Concatenated 287 out of 412 spectra
# Concatenated 288 out of 412 spectra
# Concatenated 289 out of 412 spectra
# Concatenated 290 out of 412 spectra
# Concatenated 291 out of 412 spectra
# Concatenated 292 out of 412 spectra
# Concatenated 293 out of 412 spectra
# Concatenated 294 out of 412 spectra
# Concatenated 295 out of 412 spectra
# Concatenated 296 out of 412 spectra
# Concatenated 297 out of 412 spectra
# Concatenated 298 out of 412 spectra
# Concatenated 300 out of 412 spectra
# Concatenated 301 out of 412 spectra
# Concatenated 302 out of 412 spectra
# Concatenated 303 out of 412 spectra
# Concatenated 304 out of 412 spectra
# Concatenated 305 out of 412 spectra
# Concatenated 306 out of 412 spectra
# Concatenated 307 out of 412 spectra
# Concatenated 308 out of 412 spectra
# Concatenated 309 out of 412 spectra
# Concatenated 310 out of 412 spectra
# Concatenated 311 out of 412 spectra
# Concatenated 312 out of 412 spectra
# Concatenated 313 out of 412 spectra
# Concatenated 314 out of 412 spectra
# Concatenated 315 out of 412 spectra
# Concatenated 316 out of 412 spectra
# Concatenated 317 out of 412 spectra
# Concatenated 318 out of 412 spectra
# Concatenated 319 out of 412 spectra
# Concatenated 320 out of 412 spectra
# Concatenated 321 out of 412 spectra
# Concatenated 322 out of 412 spectra
# Concatenated 323 out of 412 spectra
# Concatenated 324 out of 412 spectra
# Concatenated 325 out of 412 spectra
# Concatenated 326 out of 412 spectra
# Concatenated 327 out of 412 spectra
# Concatenated 328 out of 412 spectra
# Concatenated 329 out of 412 spectra
# Concatenated 330 out of 412 spectra
# Concatenated 331 out of 412 spectra
# Concatenated 332 out of 412 spectra
# Concatenated 333 out of 412 spectra
# Concatenated 334 out of 412 spectra
# Concatenated 335 out of 412 spectra
# Concatenated 336 out of 412 spectra
# Concatenated 337 out of 412 spectra
# Concatenated 338 out of 412 spectra
# Concatenated 339 out of 412 spectra
# Concatenated 340 out of 412 spectra
# Concatenated 341 out of 412 spectra
# Concatenated 342 out of 412 spectra
# Concatenated 343 out of 412 spectra
# Concatenated 344 out of 412 spectra
# Concatenated 345 out of 412 spectra
# Concatenated 346 out of 412 spectra
# Concatenated 347 out of 412 spectra
# Concatenated 348 out of 412 spectra
# Concatenated 349 out of 412 spectra
# Concatenated 350 out of 412 spectra
# Concatenated 351 out of 412 spectra
# Concatenated 352 out of 412 spectra
# Concatenated 353 out of 412 spectra
# Concatenated 354 out of 412 spectra
# Concatenated 355 out of 412 spectra
# Concatenated 356 out of 412 spectra
# Concatenated 357 out of 412 spectra
# Concatenated 358 out of 412 spectra
# Concatenated 360 out of 412 spectra
# Concatenated 361 out of 412 spectra
# Concatenated 362 out of 412 spectra
# Concatenated 363 out of 412 spectra
# Concatenated 364 out of 412 spectra
# Concatenated 365 out of 412 spectra
# Concatenated 366 out of 412 spectra
# Concatenated 367 out of 412 spectra
# Concatenated 368 out of 412 spectra
# Concatenated 369 out of 412 spectra
# Concatenated 370 out of 412 spectra
# Concatenated 371 out of 412 spectra
# Concatenated 372 out of 412 spectra
# Concatenated 373 out of 412 spectra
# Concatenated 374 out of 412 spectra
# Concatenated 375 out of 412 spectra
# Concatenated 376 out of 412 spectra
# Concatenated 377 out of 412 spectra
# Concatenated 378 out of 412 spectra
# Concatenated 379 out of 412 spectra
# Concatenated 380 out of 412 spectra
# Concatenated 381 out of 412 spectra
# Concatenated 382 out of 412 spectra
# Concatenated 383 out of 412 spectra
# Concatenated 384 out of 412 spectra
# Concatenated 385 out of 412 spectra
# Concatenated 386 out of 412 spectra
# Concatenated 387 out of 412 spectra
# Concatenated 388 out of 412 spectra
# Concatenated 389 out of 412 spectra
# Concatenated 390 out of 412 spectra
# Concatenated 391 out of 412 spectra
# Concatenated 392 out of 412 spectra
# Concatenated 393 out of 412 spectra
# Concatenated 394 out of 412 spectra
# Concatenated 395 out of 412 spectra
# Concatenated 396 out of 412 spectra
# Concatenated 397 out of 412 spectra
# Concatenated 398 out of 412 spectra
# Concatenated 399 out of 412 spectra
# Concatenated 400 out of 412 spectra
# Concatenated 401 out of 412 spectra
# Concatenated 402 out of 412 spectra
# Concatenated 403 out of 412 spectra
# Concatenated 404 out of 412 spectra
# Concatenated 405 out of 412 spectra
# Concatenated 406 out of 412 spectra
# Concatenated 407 out of 412 spectra
# Concatenated 408 out of 412 spectra
# Concatenated 409 out of 412 spectra
# Concatenated 410 out of 412 spectra
# Concatenated 411 out of 412 spectra
# Concatenated 412 out of 412 spectra
# Concatenated 413 out of 412 spectra
# Concatenated 414 out of 412 spectra
# Concatenated 415 out of 412 spectra
# Concatenated 416 out of 412 spectra
# Concatenated 417 out of 412 spectra
# Concatenated 418 out of 412 spectra

# %%
## Random forest training

import spectra_interpolator as si

# Use the random forest interpolator
intp = si.intp(rf=True)

# Load the simulation parameters and spectra
# t_max = None implies time used during interpolation
# theta = 0 defined in degrees

intp.load_data('knsc1_active_learning/*spec*', \
               'TP_wind2_spectra.h5', \
               t_max=None, theta=30, trim_dataset=True)

# Create verification test set

intp.create_test_set(size=5)

# Append time as the 5th input parameter
# Nominally, spectra have shape [N_sims, times, wavs, thetas]
# For free time + fixed angle, append_input_parameter(intp.times, 1)
# For free angle + fixed time, append_input_parameter(intp.angles, 2)

intp.append_input_parameter(intp.times, 1)

# Preprocess data for easier training

intp.preprocess()

# Train!

intp.train()

# Save the model

intp.save('rf_spec_intp.joblib')

# Evaluate the test set input parameters if evaluate() given no arguments
# If arguments provided, stores them under intp.prediction
# Predictions can be returned by setting argument ret_out=True 

intp.evaluate()

# Make plots of the test set to visually identify off-sample fitting
# Test set plots stored in intp_figures directory

intp.make_plots()
# Out:
# Using rf interpolator
# Parameter array shape:  (412, 4)
# Spectra times:  [ 1.41419956  1.54219501  1.68177499  1.83398798  1.99997737  2.18099002
#   2.37838564  2.59364701  2.82839112  3.0843813   3.36354047  3.66796559
#   3.99994342  4.36196769  4.75675782  5.18727935  5.65676624  6.16874514
#   6.7270619   7.33591043  7.99986422  8.72391071  9.51348872 10.37452935]
# Angle index of 2 corresponds to 31.586338 degrees
# Loading h5 file, this may take a while on the first execution
# (412, 60, 1024, 54)
# Data loaded and reshaped
# Test set parameters should be:  [[0.00101  0.187834 0.034515 0.298814]
#  [0.001392 0.291114 0.047775 0.086227]
#  [0.00149  0.222715 0.001105 0.09309 ]
#  [0.002314 0.262187 0.099887 0.162864]
#  [0.056379 0.297409 0.095523 0.05931 ]]
# Test set parameters are:  [[1.01000000e-03 1.87834000e-01 3.45150000e-02 2.98814000e-01
#   1.41419956e+00]
#  [1.39200000e-03 2.91114000e-01 4.77750000e-02 8.62270000e-02
#   1.83398798e+00]
#  [1.49000000e-03 2.22715000e-01 1.10500000e-03 9.30900000e-02
#   1.68177499e+00]
#  [2.31400000e-03 2.62187000e-01 9.98870000e-02 1.62864000e-01
#   1.68177499e+00]
#  [5.63790000e-02 2.97409000e-01 9.55230000e-02 5.93100000e-02
#   1.99997737e+00]
#  [1.26800000e-03 5.31290000e-02 3.48960000e-02 2.05983000e-01
#   1.03745293e+01]]
# Test set shape is:  (6, 5)
# Test spectra shape is  (6, 384)
# Training set shape is  (406, 4)
# Training spectra shape is  (406, 24, 384)
# (9744, 5) (9744, 384)
# Preprocessing data for training
# (384,) (384,)
# Starting training, this may take a while...
# started saving model at  time.struct_time(tm_year=2023, tm_mon=4, tm_mday=25, tm_hour=23, tm_min=0, tm_sec=36, tm_wday=1, tm_yday=115, tm_isdst=1)
# stopped saving model at  time.struct_time(tm_year=2023, tm_mon=4, tm_mday=25, tm_hour=23, tm_min=0, tm_sec=38, tm_wday=1, tm_yday=115, tm_isdst=1)
# Prediction shape is  (6, 384)
